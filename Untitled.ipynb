# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
# Collecting numpy>=1.22.4 (from pandas)
#   Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/dk/profiling_env/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in /home/dk/profiling_env/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-2.3.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 2.6 MB/s  0:00:04m 2.6 MB/s eta 0:00:01
# Downloading numpy-2.2.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.8/16.8 MB 2.4 MB/s  0:00:06 eta 0:00:010:01:01
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: pytz, tzdata, numpy, pandas
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [pandas]━━━━ 3/4 [pandas]
# Successfully installed numpy-2.2.6 pandas-2.3.3 pytz-2025.2 tzdata-2025.3

# %%
pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Using cached pandas_profiling-3.6.6-py2.py3-none-any.whl.metadata (4.5 kB)
# Collecting ydata-profiling (from pandas-profiling)
#   Using cached ydata_profiling-4.18.0-py2.py3-none-any.whl.metadata (22 kB)
# Collecting scipy<1.17,>=1.8 (from ydata-profiling->pandas-profiling)
#   Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.5 in /home/dk/profiling_env/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (2.3.3)
# Collecting matplotlib<=3.10,>=3.5 (from ydata-profiling->pandas-profiling)
#   Downloading matplotlib-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Collecting pydantic<3,>=2 (from ydata-profiling->pandas-profiling)
#   Downloading pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting PyYAML<6.1,>=6.0.3 (from ydata-profiling->pandas-profiling)
#   Using cached pyyaml-6.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.4 kB)
# Collecting jinja2<3.2,>=3.1.6 (from ydata-profiling->pandas-profiling)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting visions<0.8.2,>=0.7.5 (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling)
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy<2.4,>=1.22 in /home/dk/profiling_env/lib/python3.10/site-packages (from ydata-profiling->pandas-profiling) (2.2.6)
# Collecting minify-html>=0.15.0 (from ydata-profiling->pandas-profiling)
#   Downloading minify_html-0.18.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting filetype>=1.0.0 (from ydata-profiling->pandas-profiling)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting phik<0.13,>=0.12.5 (from ydata-profiling->pandas-profiling)
#   Downloading phik-0.12.5-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (5.6 kB)
# Collecting requests<3,>=2.32.0 (from ydata-profiling->pandas-profiling)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tqdm<5,>=4.66.3 (from ydata-profiling->pandas-profiling)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting seaborn<0.14,>=0.10.1 (from ydata-profiling->pandas-profiling)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting multimethod<2,>=1.4 (from ydata-profiling->pandas-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Collecting statsmodels<1,>=0.13.2 (from ydata-profiling->pandas-profiling)
#   Downloading statsmodels-0.14.6-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting typeguard<5,>=4 (from ydata-profiling->pandas-profiling)
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting imagehash==4.3.2 (from ydata-profiling->pandas-profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting wordcloud>=1.9.4 (from ydata-profiling->pandas-profiling)
#   Downloading wordcloud-1.9.5-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Collecting dacite<2,>=1.9 (from ydata-profiling->pandas-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting numba<0.63,>=0.60 (from ydata-profiling->pandas-profiling)
#   Downloading numba-0.62.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting PyWavelets (from imagehash==4.3.2->ydata-profiling->pandas-profiling)
#   Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Collecting pillow (from imagehash==4.3.2->ydata-profiling->pandas-profiling)
#   Using cached pillow-12.1.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting MarkupSafe>=2.0 (from jinja2<3.2,>=3.1.6->ydata-profiling->pandas-profiling)
#   Downloading markupsafe-3.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (2.7 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling)
#   Using cached contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling)
#   Using cached fonttools-4.61.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling)
#   Using cached kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /home/dk/profiling_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (25.0)
# Collecting pyparsing>=2.3.1 (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling)
#   Using cached pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/dk/profiling_env/lib/python3.10/site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (2.9.0.post0)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba<0.63,>=0.60->ydata-profiling->pandas-profiling)
#   Downloading llvmlite-0.45.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: pytz>=2020.1 in /home/dk/profiling_env/lib/python3.10/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling->pandas-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/dk/profiling_env/lib/python3.10/site-packages (from pandas!=1.4.0,<3.0,>1.5->ydata-profiling->pandas-profiling) (2025.3)
# Collecting joblib>=0.14.1 (from phik<0.13,>=0.12.5->ydata-profiling->pandas-profiling)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=2->ydata-profiling->pandas-profiling)
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic<3,>=2->ydata-profiling->pandas-profiling)
#   Downloading pydantic_core-2.41.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: typing-extensions>=4.14.1 in /home/dk/profiling_env/lib/python3.10/site-packages (from pydantic<3,>=2->ydata-profiling->pandas-profiling) (4.15.0)
# Collecting typing-inspection>=0.4.2 (from pydantic<3,>=2->ydata-profiling->pandas-profiling)
#   Downloading typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.32.0->ydata-profiling->pandas-profiling)
#   Downloading charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.32.0->ydata-profiling->pandas-profiling)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.32.0->ydata-profiling->pandas-profiling)
#   Downloading urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.32.0->ydata-profiling->pandas-profiling)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting patsy>=0.5.6 (from statsmodels<1,>=0.13.2->ydata-profiling->pandas-profiling)
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Collecting attrs>=19.3.0 (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling)
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting networkx>=2.4 (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling)
#   Using cached networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting puremagic (from visions<0.8.2,>=0.7.5->visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling)
#   Downloading puremagic-1.30-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: six>=1.5 in /home/dk/profiling_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.17.0)
# Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
# Downloading ydata_profiling-4.18.0-py2.py3-none-any.whl (398 kB)
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading matplotlib-3.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 5.3 MB/s  0:00:01a 0:00:010:00:01:01
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading numba-0.62.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 4.6 MB/s  0:00:00m 5.4 MB/s eta 0:00:01
# Downloading llvmlite-0.45.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.2 MB/s  0:00:17 eta 0:00:010:00:01
# Downloading phik-0.12.5-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (677 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.6/677.6 kB 405.3 kB/s  0:00:01.9 kB/s eta 0:00:01
# Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
# Downloading pydantic_core-2.41.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 1.7 MB/s  0:00:011.7 MB/s eta 0:00:01
# Downloading pyyaml-6.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (770 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.3/770.3 kB 2.2 MB/s  0:00:00m ? eta -:--:--
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (153 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading scipy-1.15.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.7/37.7 MB 3.4 MB/s  0:00:11 eta 0:00:010:00:01
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Downloading statsmodels-0.14.6-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 3.4 MB/s  0:00:033.5 MB/s eta 0:00:01
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typeguard-4.4.4-py3-none-any.whl (34 kB)
# Downloading urllib3-2.6.2-py3-none-any.whl (131 kB)
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading fonttools-4.61.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 3.6 MB/s  0:00:01m 3.7 MB/s eta 0:00:01
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading kiwisolver-1.4.9-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 4.4 MB/s  0:00:004.7 MB/s eta 0:00:01
# Downloading markupsafe-3.0.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (20 kB)
# Downloading minify_html-0.18.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 2.9 MB/s  0:00:012.9 MB/s eta 0:00:01
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 4.0 MB/s  0:00:00m 4.4 MB/s eta 0:00:01
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
# Downloading pillow-12.1.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 3.6 MB/s  0:00:01m 3.8 MB/s eta 0:00:01
# Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
# Downloading typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Downloading wordcloud-1.9.5-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (526 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.4/526.4 kB 3.6 MB/s  0:00:00
# Downloading puremagic-1.30-py3-none-any.whl (43 kB)
# Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 3.2 MB/s  0:00:013.2 MB/s eta 0:00:01:01
# Installing collected packages: puremagic, minify-html, filetype, urllib3, typing-inspection, typeguard, tqdm, scipy, PyYAML, PyWavelets, pyparsing, pydantic-core, pillow, patsy, networkx, multimethod, MarkupSafe, llvmlite, kiwisolver, joblib, idna, fonttools, dacite, cycler, contourpy, charset_normalizer, certifi, attrs, annotated-types, requests, pydantic, numba, matplotlib, jinja2, imagehash, wordcloud, visions, statsmodels, seaborn, phik, ydata-profiling, pandas-profiling
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42/42 [pandas-profiling]ndas-profiling]ata-profiling]ormalizer]
# Successfully installed MarkupSafe-3.0.3 PyWavelets-1.8.0 PyYAML-6.0.3 annotated-types-0.7.0 attrs-25.4.0 certifi-2025.11.12 charset_normalizer-3.4.4 contourpy-1.3.2 cycler-0.12.1 dacite-1.9.2 filetype-1.2.0 fonttools-4.61.1 idna-3.11 imagehash-4.3.2 jinja2-3.1.6 joblib-1.5.3 kiwisolver-1.4.9 llvmlite-0.45.1 matplotlib-3.10.0 minify-html-0.18.1 multimethod-1.12 networkx-3.4.2 numba-0.62.1 pandas-profiling-3.6.6 patsy-1.0.2 phik-0.12.5 pillow-12.1.0 puremagic-1.30 pydantic-2.12.5 pydantic-core-2.41.5 pyparsing-3.3.1 requests-2.32.5 scipy-1.15.3 seaborn-0.13.2 statsmodels-0.14.6 tqdm-4.67.1 typeguard-4.4.4 typing-inspection-0.4.2 urllib3-2.6.2 visions-0.8.1 wordcloud-1.9.5 ydata-profiling-4.18.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from pandas_profiling import ProfileReport

df = pd.read_csv("test_data.csv")

profile = ProfileReport(df, explorative=True)
profile.to_file("pandas_profile_report.html")
# Out:
# ---------------------------------------------------------------------------
# PydanticImportError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 from pandas_profiling import ProfileReport
#       4 df = pd.read_csv("test_data.csv")
#       6 profile = ProfileReport(df, explorative=True)
#
# File ~/profiling_env/lib/python3.10/site-packages/pandas_profiling/__init__.py:8
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
#       6 from warnings import warn
# ----> 8 from pandas_profiling.compare_reports import compare
#       9 from pandas_profiling.controller import pandas_decorator
#      10 from pandas_profiling.profile_report import ProfileReport
#
# File ~/profiling_env/lib/python3.10/site-packages/pandas_profiling/compare_reports.py:6
#       2 from typing import Any, List, Optional, Tuple, Union
#       4 import pandas as pd
# ----> 6 from pandas_profiling.config import Correlation, Settings
#       7 from pandas_profiling.model.alerts import Alert
#       8 from pandas_profiling.profile_report import ProfileReport
#
# File ~/profiling_env/lib/python3.10/site-packages/pandas_profiling/config.py:7
#       4 from typing import Any, Dict, List, Optional, Tuple, Union
#       6 import yaml
# ----> 7 from pydantic import BaseModel, BaseSettings, Field, PrivateAttr
#      10 def _merge_dictionaries(dict1: dict, dict2: dict) -> dict:
#      11     """
#      12     Recursive merge dictionaries.
#      13
#    (...)
#      16     :return: Merged dictionary
#      17     """
#
# File ~/profiling_env/lib/python3.10/site-packages/pydantic/__init__.py:437, in __getattr__(attr_name)
#     435 dynamic_attr = _dynamic_imports.get(attr_name)
#     436 if dynamic_attr is None:
# --> 437     return _getattr_migration(attr_name)
#     439 package, module_name = dynamic_attr
#     441 if module_name == '__module__':
#
# File ~/profiling_env/lib/python3.10/site-packages/pydantic/_migration.py:304, in getattr_migration.<locals>.wrapper(name)
#     302     return import_string(REDIRECT_TO_V1[import_path])
#     303 if import_path == 'pydantic:BaseSettings':
# --> 304     raise PydanticImportError(
#     305         '`BaseSettings` has been moved to the `pydantic-settings` package. '
#     306         f'See https://docs.pydantic.dev/{version_short()}/migration/#basesettings-has-moved-to-pydantic-settings '
#     307         'for more details.'
#     308     )
#     309 if import_path in REMOVED_IN_V2:
#     310     raise PydanticImportError(f'`{import_path}` has been removed in V2.')
#
# PydanticImportError: `BaseSettings` has been moved to the `pydantic-settings` package. See https://docs.pydantic.dev/2.12/migration/#basesettings-has-moved-to-pydantic-settings for more details.
#
# For further information visit https://errors.pydantic.dev/2.12/u/import-error
