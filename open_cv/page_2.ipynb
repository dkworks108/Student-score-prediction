# %%
import cv2

# %%
image = cv2.imread('lion.jpg')

# %%
cv2.imshow("image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ...
# QObject::moveToThread: Current thread (0x22bfb900) is not the object's thread (0x22fcb310).
# Cannot move to target thread (0x22bfb900)
#
# QObject::moveToThread: Current thread (0x22bfb900) is not the object's thread (0x22fcb310).
# Cannot move to target thread (0x22bfb900)
#
# QObject::moveToThread: Current thread (0x22bfb900) is not the object's thread (0x22fcb310).
# Cannot move to target thread (0x22bfb900)
#
# QObject::moveToThread: Current thread (0x22bfb900) is not the object's thread (0x22fcb310).
# Cannot move to target thread (0x22bfb900)
#
# QObject::moveToThread: Current thread (0x22bfb900) is not the object's thread (0x22fcb310).
# Cannot move to target thread (0x22bfb900)
#
# QObject::moveToThread: Current thread (0x22bfb900) is not the object's thread (0x22fcb310).
# Cannot move to target thread (0x22bfb900)
#
# QObject::moveToThread: Current thread (0x22bfb900) is not the object's thread (0x22fcb310).
# Cannot move to target thread (0x22bfb900)
#
# ...

# %%
reszided =  cv2.resize(image,(1080, 756 ))

cv2.imshow("hello ", reszided)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x22bfb900) is not the object's thread (0x22fcb310).
# Cannot move to target thread (0x22bfb900)
#
# QObject::moveToThread: Current thread (0x22bfb900) is not the object's thread (0x22fcb310).
# Cannot move to target thread (0x22bfb900)
#
# QObject::moveToThread: Current thread (0x22bfb900) is not the object's thread (0x22fcb310).
# Cannot move to target thread (0x22bfb900)
#
# QObject::moveToThread: Current thread (0x22bfb900) is not the object's thread (0x22fcb310).
# Cannot move to target thread (0x22bfb900)
#
# QObject::moveToThread: Current thread (0x22bfb900) is not the object's thread (0x22fcb310).
# Cannot move to target thread (0x22bfb900)
#
# QObject::moveToThread: Current thread (0x22bfb900) is not the object's thread (0x22fcb310).
# Cannot move to target thread (0x22bfb900)
#
# QObject::moveToThread: Current thread (0x22bfb900) is not the object's thread (0x22fcb310).
# Cannot move to target thread (0x22bfb900)
#
# ...

# %%
new_high = cv2.imwrite("sher_high.tiff", reszided)
